# %%
# Step 1: Install required libs (run once)
# !pip install transformers datasets scikit-learn torch pandas --quiet

# Step 2: Imports
import pandas as pd
import torch
import numpy as np
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    Trainer,
    TrainingArguments,
    DataCollatorWithPadding,
    pipeline,
)
from datasets import Dataset
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score

# Step 3: Load your CSV dataset
df = pd.read_csv("customer_support_tickets.csv")

# Step 4: Prepare input text and labels
df['text'] = df['Ticket Subject'].fillna('') + ". " + df['Ticket Description'].fillna('')
df = df.dropna(subset=['Ticket Type', 'text'])

label_encoder = LabelEncoder()
df['label'] = label_encoder.fit_transform(df['Ticket Type'])
print(f"Classes (tags): {list(label_encoder.classes_)}")

dataset = Dataset.from_pandas(df[['text', 'label']])

# Step 5: Tokenize dataset (batched=True for padding consistency)
model_name = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)

def tokenize_fn(batch):
    return tokenizer(batch["text"], padding=True, truncation=True, max_length=256)

tokenized_dataset = dataset.map(tokenize_fn, batched=True)

# Step 6: Split dataset (train/test)
split = tokenized_dataset.train_test_split(test_size=0.2, seed=42)
train_dataset = split['train']
test_dataset = split['test']

# Step 7: Load model for sequence classification
num_labels = len(label_encoder.classes_)
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=num_labels)

# Step 8: Define training arguments with report_to="none" to silence warnings
training_args = TrainingArguments(
    output_dir="./ticket_classifier",
    eval_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
    save_strategy="epoch",
    report_to="none"
)

# Step 9: Metrics function
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=-1)
    acc = accuracy_score(labels, preds)
    f1 = f1_score(labels, preds, average='weighted')
    return {"accuracy": acc, "f1": f1}

# Step 10: Use DataCollatorWithPadding for dynamic batch padding
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics,
    data_collator=data_collator,  # Important for padding batches dynamically
)

# Step 11: Train the model
trainer.train()

#Fix for your prediction loop (Step 12):
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

print("Top 3 tags per ticket (test set):")
for example in test_dataset:
    inputs = tokenizer(example['text'], return_tensors="pt", truncation=True, padding=True, max_length=256)
    inputs = {k: v.to(device) for k, v in inputs.items()}  # <-- move inputs to model device
    with torch.no_grad():
        outputs = model(**inputs)
        probs = F.softmax(outputs.logits, dim=-1)[0]
    top3 = torch.topk(probs, k=3)
    tags = [label_encoder.classes_[i] for i in top3.indices.cpu().numpy()]
    scores = top3.values.cpu().numpy()
    print(f"Ticket text (first 60 chars): {example['text'][:60]!r}")
    for tag, score in zip(tags, scores):
        print(f"  {tag}: {score:.3f}")
    print()


# Step 13 (optional): Zero-shot classification for comparison
zero_shot_classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
candidate_labels = list(label_encoder.classes_)

print("Zero-shot classification example:")
for text in df['text'].sample(3, random_state=42):
    result = zero_shot_classifier(text, candidate_labels, multi_label=True)
    print(f"Text (first 60 chars): {text[:60]!r}")
    for label, score in zip(result['labels'][:3], result['scores'][:3]):
        print(f"  {label}: {score:.3f}")
    print()
# Out:
# Classes (tags): ['Billing inquiry', 'Cancellation request', 'Product inquiry', 'Refund request', 'Technical issue']
# Map:   0%|          | 0/8469 [00:00<?, ? examples/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='2541' max='2541' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2541/2541 07:15, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.618100</td>
#       <td>1.608834</td>
#       <td>0.212515</td>
#       <td>0.124649</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.617500</td>
#       <td>1.609197</td>
#       <td>0.207792</td>
#       <td>0.071498</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.612300</td>
#       <td>1.608951</td>
#       <td>0.207202</td>
#       <td>0.084645</td>
#     </tr>
#   </tbody>
# </table><p>
# Streaming output truncated to the last 5000 lines.
# Ticket text (first 60 chars): "Data loss. I'm having an issue with the {product_purchased}."
#   Refund request: 0.207
#   Technical issue: 0.206
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): 'Payment issue. There seems to be a hardware problem with my '
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Payment issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Battery life. I'm having trouble connecting my {product_purc"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Cancellation request. I'm facing issues logging into my {pro"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Network problem. I'm having an issue with the {product_purch"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Software bug. I'm having an issue with the {product_purchase"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): 'Installation support. My {product_purchased} is making stran'
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): 'Account access. The {product_purchased} is unable to establi'
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Software bug. I'm having an issue with the {product_purchase"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Network problem. I'm having an issue with the {product_purch"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): 'Peripheral compatibility. My {product_purchased} is making s'
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Data loss. I'm having an issue with the {product_purchased}."
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Software bug. I'm having trouble connecting my {product_purc"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Refund request. I'm unable to access my {product_purchased} "
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): 'Refund request. There seems to be a glitch in the {product_p'
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.196
#
# Ticket text (first 60 chars): "Data loss. I'm having an issue with the {product_purchased}."
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product recommendation. I'm facing a problem with my {produc"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Cancellation request. I'm having an issue with the {product_"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.210
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product compatibility. I'm having an issue with the {product"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): 'Software bug. There seems to be a hardware problem with my {'
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Software bug. I'm having an issue with the {product_purchase"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Account access. I've forgotten my password for my {product_p"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Technical issue: 0.207
#   Refund request: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Account access. I'm facing issues logging into my {product_p"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Data loss. I'm having an issue with the {product_purchased}."
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): 'Cancellation request. The {product_purchased} is unable to e'
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.196
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Cancellation request. I'm having an issue with the {product_"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Technical issue: 0.208
#   Refund request: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Network problem. I'm having an issue with the {product_purch"
#   Refund request: 0.211
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Installation support. I'm having an issue with the {product_"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Display issue. I've noticed a software bug in the {product_p"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Data loss. I'm having an issue with the {product_purchased}."
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): 'Network problem. The {product_purchased} is unable to establ'
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Cancellation request. I'm having an issue with the {product_"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Data loss. I'm having an issue with the {product_purchased}."
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product compatibility. I'm having an issue with the {product"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): 'Account access. There seems to be a hardware problem with my'
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Installation support. I'm having an issue with the {product_"
#   Refund request: 0.211
#   Technical issue: 0.206
#   Cancellation request: 0.196
#
# Ticket text (first 60 chars): "Display issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Payment issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Installation support. I'm having an issue with the {product_"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Network problem. I'm having an issue with the {product_purch"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Hardware issue. I'm facing issues logging into my {product_p"
#   Refund request: 0.211
#   Technical issue: 0.205
#   Cancellation request: 0.196
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Software bug. I'm having an issue with the {product_purchase"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Delivery problem. I'm having an issue with the {product_purc"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Display issue. I've noticed a software bug in the {product_p"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Display issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): 'Cancellation request. My {product_purchased} is making stran'
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.211
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product compatibility. I've forgotten my password for my {pr"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Delivery problem. I'm having an issue with the {product_purc"
#   Technical issue: 0.208
#   Refund request: 0.206
#   Cancellation request: 0.200
#
# Ticket text (first 60 chars): "Data loss. I'm having an issue with the {product_purchased}."
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Installation support. I've encountered a data loss issue wit"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Product inquiry: 0.198
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Installation support. I'm having an issue with the {product_"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Cancellation request. I'm having an issue with the {product_"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): 'Data loss. My {product_purchased} is making strange noises a'
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Display issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Delivery problem. I'm having an issue with the {product_purc"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Technical issue: 0.207
#   Refund request: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Cancellation request. I'm facing a problem with my {product_"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Delivery problem. I'm having an issue with the {product_purc"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product recommendation. I've encountered a data loss issue w"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Software bug. I'm facing issues logging into my {product_pur"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product compatibility. I'm having an issue with the {product"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Product recommendation. I'm facing issues logging into my {p"
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Software bug. I'm having an issue with the {product_purchase"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Installation support. I'm facing a problem with my {product_"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Hardware issue. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Payment issue. I've encountered a data loss issue with my {p"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.210
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Display issue. I've recently set up my {product_purchased}, "
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Display issue. I'm unable to access my {product_purchased} a"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product compatibility. I'm having an issue with the {product"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Display issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Payment issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): 'Payment issue. My {product_purchased} crashed, and I lost al'
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): 'Software bug. The {product_purchased} is unable to establish'
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Battery life. I'm encountering a software bug in the {produc"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product compatibility. I'm having an issue with the {product"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product compatibility. I'm unable to access my {product_purc"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Account access. I've forgotten my password for my {product_p"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product compatibility. I'm having an issue with the {product"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Data loss. I'm having an issue with the {product_purchased}."
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Payment issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Cancellation request. I'm having an issue with the {product_"
#   Technical issue: 0.207
#   Refund request: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Product recommendation. I've recently set up my {product_pur"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): 'Software bug. The {product_purchased} is unable to establish'
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product compatibility. I'm having an issue with the {product"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Delivery problem. I'm encountering a software bug in the {pr"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.196
#
# Ticket text (first 60 chars): "Product compatibility. I've noticed a software bug in the {p"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): 'Delivery problem. There seems to be a hardware problem with '
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Delivery problem. I'm unable to access my {product_purchased"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product compatibility. I've noticed a software bug in the {p"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): 'Delivery problem. My {product_purchased} crashed, and I lost'
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Network problem. I'm having an issue with the {product_purch"
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product setup. I'm facing issues logging into my {product_pu"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Hardware issue. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Hardware issue. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): 'Hardware issue. There seems to be a glitch in the {product_p'
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.196
#
# Ticket text (first 60 chars): "Cancellation request. I'm having an issue with the {product_"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): 'Account access. There seems to be a hardware problem with my'
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Technical issue: 0.208
#   Refund request: 0.206
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Product recommendation. I've noticed a software bug in the {"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.196
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Battery life. I've encountered a data loss issue with my {pr"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Delivery problem. I've accidentally deleted important data f"
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Payment issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): 'Data loss. There seems to be a hardware problem with my {pro'
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Refund request. I've encountered a data loss issue with my {"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Delivery problem. I'm having an issue with the {product_purc"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Software bug. I'm having an issue with the {product_purchase"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Hardware issue. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Data loss. I'm having trouble connecting my {product_purchas"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product recommendation. I'm facing issues logging into my {p"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Software bug. I'm having an issue with the {product_purchase"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Data loss. I'm having an issue with the {product_purchased}."
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Network problem. I'm having an issue with the {product_purch"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Cancellation request. I'm having an issue with the {product_"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Battery life. I've accidentally deleted important data from "
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Software bug. I'm having an issue with the {product_purchase"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Installation support. I've recently set up my {product_purch"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Installation support. I'm having an issue with the {product_"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product recommendation. I've recently set up my {product_pur"
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Software bug. I'm having an issue with the {product_purchase"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): 'Product compatibility. My {product_purchased} crashed, and I'
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Technical issue: 0.207
#   Refund request: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Hardware issue. I've accidentally deleted important data fro"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Data loss. I'm having an issue with the {product_purchased}."
#   Refund request: 0.210
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Cancellation request. I'm having an issue with the {product_"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Hardware issue. I'm facing a problem with my {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Payment issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Display issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Product compatibility. I'm having an issue with the {product"
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): 'Product recommendation. There seems to be a glitch in the {p'
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.211
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Network problem. I'm having trouble connecting my {product_p"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Data loss. I've accidentally deleted important data from my "
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.196
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Account access. I'm facing issues logging into my {product_p"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Display issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Cancellation request. I'm having an issue with the {product_"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Payment issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): 'Refund request. There seems to be a hardware problem with my'
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Cancellation request. I'm having an issue with the {product_"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Display issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Installation support. I'm having an issue with the {product_"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Display issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.196
#
# Ticket text (first 60 chars): "Cancellation request. I'm having an issue with the {product_"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Delivery problem. I'm having an issue with the {product_purc"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Payment issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Delivery problem. I've recently set up my {product_purchased"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Hardware issue. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): 'Software bug. There seems to be a hardware problem with my {'
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Network problem. I'm having an issue with the {product_purch"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Payment issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.211
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Display issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Cancellation request. I'm encountering a software bug in the"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Hardware issue. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Installation support. I'm having an issue with the {product_"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Delivery problem. I'm having an issue with the {product_purc"
#   Refund request: 0.210
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Account access. I've noticed a software bug in the {product_"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Payment issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product compatibility. I've forgotten my password for my {pr"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Delivery problem. I'm having an issue with the {product_purc"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Delivery problem. I'm having an issue with the {product_purc"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Installation support. I'm having an issue with the {product_"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): 'Peripheral compatibility. There seems to be a hardware probl'
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Cancellation request. I'm having an issue with the {product_"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Data loss. I'm having an issue with the {product_purchased}."
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Hardware issue. I'm having an issue with the {product_purcha"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Data loss. I've recently set up my {product_purchased}, but "
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Payment issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Hardware issue. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Software bug. I'm having an issue with the {product_purchase"
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Hardware issue. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Delivery problem. I'm having an issue with the {product_purc"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Network problem. I'm having an issue with the {product_purch"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Payment issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Technical issue: 0.207
#   Refund request: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Installation support. I'm unable to access my {product_purch"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Hardware issue. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Data loss. I've noticed a software bug in the {product_purch"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Payment issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Delivery problem. I'm having trouble connecting my {product_"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Installation support. I'm having an issue with the {product_"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Refund request. I'm unable to access my {product_purchased} "
#   Refund request: 0.207
#   Technical issue: 0.206
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Display issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Cancellation request. I've forgotten my password for my {pro"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Hardware issue. I've encountered a data loss issue with my {"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# ...
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product setup. I've accidentally deleted important data from"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Refund request. I'm facing a problem with my {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Delivery problem. I'm having an issue with the {product_purc"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Software bug. I've accidentally deleted important data from "
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Data loss. I'm having an issue with the {product_purchased}."
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Payment issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Delivery problem. I'm encountering a software bug in the {pr"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Software bug. I'm encountering a software bug in the {produc"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Payment issue. I've encountered a data loss issue with my {p"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Hardware issue. I'm facing issues logging into my {product_p"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Hardware issue. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Installation support. I'm having an issue with the {product_"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Installation support. I'm having an issue with the {product_"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Display issue. I've forgotten my password for my {product_pu"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Data loss. I'm having an issue with the {product_purchased}."
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Hardware issue. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product compatibility. I'm facing issues logging into my {pr"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Delivery problem. I'm having an issue with the {product_purc"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Network problem. I'm encountering a software bug in the {pro"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Delivery problem. I'm having an issue with the {product_purc"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): 'Payment issue. My {product_purchased} is making strange nois'
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): 'Data loss. There seems to be a glitch in the {product_purcha'
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.196
#
# Ticket text (first 60 chars): "Product compatibility. I'm having an issue with the {product"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): 'Peripheral compatibility. My {product_purchased} crashed, an'
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Software bug. I'm having an issue with the {product_purchase"
#   Refund request: 0.211
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product setup. I've forgotten my password for my {product_pu"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Display issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Payment issue. I'm encountering a software bug in the {produ"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Payment issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product recommendation. I've recently set up my {product_pur"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product compatibility. I'm having an issue with the {product"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Account access. I'm facing a problem with my {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Installation support. I'm having an issue with the {product_"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Network problem. I'm having an issue with the {product_purch"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Delivery problem. I've accidentally deleted important data f"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Account access. I've accidentally deleted important data fro"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Technical issue: 0.208
#   Refund request: 0.206
#   Cancellation request: 0.200
#
# Ticket text (first 60 chars): "Installation support. I'm having an issue with the {product_"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.208
#   Technical issue: 0.208
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Cancellation request. I'm having an issue with the {product_"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): 'Payment issue. My {product_purchased} is making strange nois'
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Display issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Data loss. I'm having an issue with the {product_purchased}."
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Delivery problem. I'm having an issue with the {product_purc"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): 'Hardware issue. There seems to be a hardware problem with my'
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Payment issue. I've recently set up my {product_purchased}, "
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Delivery problem. I'm having an issue with the {product_purc"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): "Data loss. I'm having an issue with the {product_purchased}."
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Refund request. I've noticed a software bug in the {product_"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Account access. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Hardware issue. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Network problem. I'm having an issue with the {product_purch"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Installation support. I'm facing issues logging into my {pro"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Cancellation request. I'm having an issue with the {product_"
#   Technical issue: 0.207
#   Refund request: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): 'Product setup. There seems to be a glitch in the {product_pu'
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Software bug. I'm facing a problem with my {product_purchase"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product setup. I've noticed a software bug in the {product_p"
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Installation support. I'm having an issue with the {product_"
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Product recommendation. I'm unable to access my {product_pur"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): 'Product compatibility. The {product_purchased} is unable to '
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Cancellation request. I'm having an issue with the {product_"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.209
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Battery life. I'm having an issue with the {product_purchase"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Product recommendation. I'm having an issue with the {produc"
#   Refund request: 0.208
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Delivery problem. I've noticed a software bug in the {produc"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Cancellation request. I'm facing issues logging into my {pro"
#   Refund request: 0.211
#   Technical issue: 0.205
#   Cancellation request: 0.196
#
# Ticket text (first 60 chars): "Cancellation request. I'm having an issue with the {product_"
#   Refund request: 0.209
#   Technical issue: 0.206
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Peripheral compatibility. I'm having an issue with the {prod"
#   Refund request: 0.207
#   Technical issue: 0.207
#   Cancellation request: 0.199
#
# Ticket text (first 60 chars): 'Product setup. There seems to be a glitch in the {product_pu'
#   Refund request: 0.210
#   Technical issue: 0.206
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Delivery problem. I'm having an issue with the {product_purc"
#   Refund request: 0.210
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): 'Account access. The {product_purchased} is unable to establi'
#   Refund request: 0.209
#   Technical issue: 0.205
#   Cancellation request: 0.197
#
# Ticket text (first 60 chars): "Display issue. I'm having an issue with the {product_purchas"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Software bug. I'm having an issue with the {product_purchase"
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
#
# Ticket text (first 60 chars): "Data loss. I'm having an issue with the {product_purchased}."
#   Refund request: 0.208
#   Technical issue: 0.207
#   Cancellation request: 0.198
# Device set to use cuda:0
# Zero-shot classification example:
# Text (first 60 chars): "Product setup. I'm having an issue with the {product_purchas"
#   Technical issue: 0.917
#   Product inquiry: 0.872
#   Refund request: 0.251
#
# Text (first 60 chars): "Battery life. I'm having trouble connecting my {product_purc"
#   Product inquiry: 0.872
#   Technical issue: 0.815
#   Billing inquiry: 0.273
#
# Text (first 60 chars): "Refund request. I'm having an issue with the {product_purcha"
#   Refund request: 0.993
#   Product inquiry: 0.849
#   Technical issue: 0.656
